# %%
install.packages("HSAUR3")
install.packages("data.table")
install.packages("lattice")
install.packages("corrplot")
library(corrplot)
library(HSAUR3)
library(data.table)
library(lattice)
data(Forbes2000)
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %% [markdown]
# # Task 1
# investigate what the data is about?
#  - what do you think the data columns mean
#  - what kind of relations you can find

# %%
summary(Forbes2000)
# Out:
#       rank            name                     country
#  Min.   :   1.0   Length:2000        United States :751
#  1st Qu.: 500.8   Class :character   Japan         :316
#  Median :1000.5   Mode  :character   United Kingdom:137
#  Mean   :1000.5                      Germany       : 65
#  3rd Qu.:1500.2                      France        : 63
#  Max.   :2000.0                      Canada        : 56
#                                      (Other)       :612
#                    category        sales            profits
#  Banking               : 313   Min.   :  0.010   Min.   :-25.8300
#  Diversified financials: 158   1st Qu.:  2.018   1st Qu.:  0.0800
#  Insurance             : 112   Median :  4.365   Median :  0.2000
#  Utilities             : 110   Mean   :  9.697   Mean   :  0.3811
#  Materials             :  97   3rd Qu.:  9.547   3rd Qu.:  0.4400
#  Oil & gas operations  :  90   Max.   :256.330   Max.   : 20.9600
#  (Other)               :1120                     NA's   :5
# ...

# %%
Forbes2000
# Out:
#      rank name                      country
# 1     1   Citigroup                 United States
# 2     2   General Electric          United States
# 3     3   American Intl Group       United States
# 4     4   ExxonMobil                United States
# 5     5   BP                        United Kingdom
# 6     6   Bank of America           United States
# 7     7   HSBC Group                United Kingdom
# 8     8   Toyota Motor              Japan
# 9     9   Fannie Mae                United States
# 10   10   Wal-Mart Stores           United States
# 11   11   UBS                       Switzerland
# 12   12   ING Group                 Netherlands
# 13   13   Royal Dutch/Shell Group   Netherlands/ United Kingdom
# 14   14   Berkshire Hathaway        United States
# 15   15   JP Morgan Chase           United States
# 16   16   IBM                       United States
# 17   17   Total                     France
# 18   18   BNP Paribas               France
# ...

# %%
xyplot(data=Forbes2000, marketvalue ~ (profits+sales+assets))
# Out:
# plot without title

# %% [markdown]
# Data columns show the sales, profits, assets and market value of Forbes 2000 companies

# %% [markdown]
# # Task 2
# create a simple model to "explain" variable "marketvalue" and assume that all lines are coming from same population

# %%
forbes_lm1 <- lm(marketvalue ~ profits, data=Forbes2000)

# %%
summary(forbes_lm1)
# Out:
# Call:
# lm(formula = marketvalue ~ profits, data = Forbes2000)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -41.339  -7.321  -5.347  -0.983 283.323
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   9.0064     0.4696   19.18   <2e-16 ***
# profits       7.5899     0.2600   29.19   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 20.5 on 1993 degrees of freedom
#   (5 observations deleted due to missingness)
# Multiple R-squared:  0.2994,	Adjusted R-squared:  0.2991
# F-statistic: 851.9 on 1 and 1993 DF,  p-value: < 2.2e-16

# %%
forbes_lm2 <- lm(marketvalue ~ profits + assets + sales, data = Forbes2000)

# %%
summary(forbes_lm2)
# Out:
# Call:
# lm(formula = marketvalue ~ profits + assets + sales, data = Forbes2000)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -121.629   -4.062   -2.094    0.741  224.796
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 2.900394   0.423584   6.847 9.99e-12 ***
# profits     4.597533   0.230081  19.982  < 2e-16 ***
# assets      0.048915   0.004115  11.887  < 2e-16 ***
# sales       0.574732   0.024277  23.674  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 16.56 on 1991 degrees of freedom
#   (5 observations deleted due to missingness)
# Multiple R-squared:  0.5435,	Adjusted R-squared:  0.5428
# F-statistic: 790.1 on 3 and 1991 DF,  p-value: < 2.2e-16

# %%
pairs(Forbes2000[5:8])
# Out:
# plot without title

# %%
xyplot(marketvalue~profits, data = Forbes2000, t=c("p", "r"))
# Out:
# plot without title

# %%
xyplot(marketvalue~(profits+sales+assets), data = Forbes2000, t=c("p", "r"))
# Out:
# plot without title

# %% [markdown]
# # Task 3
# find out is that true that all rows come from same population
#   - why do you claim so
#   - if they are not, what are the populations and why do you say so

# %%
any(is.na(Forbes2000[6]))
# Out:
# [1] TRUE

# %%
Forbes2000[!complete.cases(Forbes2000),]
# Out:
#      rank name                  country        category
# 772   772 AMP                   Australia      Insurance
# 1085 1085 HHG                   United Kingdom Insurance
# 1091 1091 NTL                   United States  Telecommunications services
# 1425 1425 US Airways Group      United States  Transportation
# 1909 1909 Laidlaw International United States  Transportation
#      sales profits assets marketvalue
# 772  5.40  NA      42.94  6.70
# 1085 5.68  NA      51.65  2.07
# 1091 3.50  NA      10.59  5.94
# 1425 5.50  NA       8.58  0.24
# 1909 4.48  NA       3.98  1.49

# %% [markdown]
# Some data is missing

# %% [markdown]
# # Task 4
# find out the important variables to explain the MARKETVALUE
#   - what makes you think they are the right variables

# %%
Forbes2000_filtered <- na.omit(Forbes2000)
cor(subset(Forbes2000_filtered[5:8]))
# Out:
#             sales     profits   assets    marketvalue
# sales       1.0000000 0.4042672 0.4261359 0.6419901
# profits     0.4042672 1.0000000 0.2243573 0.5472202
# assets      0.4261359 0.2243573 1.0000000 0.4539952
# marketvalue 0.6419901 0.5472202 0.4539952 1.0000000

# %%
corrplot(cor(na.omit(Forbes2000[5:8])), method = "color")
# Out:
# Plot with title “”

# %% [markdown]
# Sales has strongest correlation to marketvalue
